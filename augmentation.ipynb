# %% [markdown]
# <a href="https://colab.research.google.com/github/aditigedam/ML/blob/main/augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import matplotlib.pyplot as plt
import numpy as np

# %%
img = load_img('/content/drive/MyDrive/datasets/1234/bird.jfif')

# %%
plt.imshow(img)

# %%
img_np_arr = img_to_array(img)
expanded_sample = np.expand_dims(img_np_arr,0)

# %%
expanded_sample.shape
# Out:
# (1, 169, 301, 3)

# %%
it = datagen.flow(expanded_sample, batch_size=5)

# %%
#featurewise_center
fig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(featurewise_center=True)
it = datagen.flow(expanded_sample, batch_size=5)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[1].set_title('original')
axes[0].set_title('featurewise_center')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Text(0.5, 1.0, 'featurewise_center')

# %%
 
fig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(rotation_range=(0-180))
it = datagen.flow(expanded_sample, batch_size=5)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[1].set_title('original')
axes[0].set_title('rotation')
# Out:
# Text(0.5, 1.0, 'rotation')

# %%
 
fig,axes = plt.subplots(3,3,figsize=(5,5))
datagen = ImageDataGenerator(rotation_range=(90-360))
it = datagen.flow(expanded_sample, batch_size=5)
for i in range(9):
  batch = it.next()
  axes[int(i/3),i%3].imshow(batch[0].astype('uint8'))
  axes[int(i/3),i%3].get_xaxis().set_visible(False)
  axes[int(i/3),i%3].get_yaxis().set_visible(False)

# %%
 
fig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator( width_shift_range=100)
it = datagen.flow(expanded_sample, batch_size=5)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[1].set_title('original')
axes[0].set_title('width_shift_range')
# Out:
# Text(0.5, 1.0, 'width_shift_range')

# %%
fig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator( height_shift_range=100)
it = datagen.flow(expanded_sample, batch_size=5)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[1].set_title('original')
axes[0].set_title('height_shift_range')
# Out:
# Text(0.5, 1.0, 'height_shift_range')

# %%
fig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(brightness_range=[0.1,0.7])
it = datagen.flow(expanded_sample, batch_size=5)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[0].set_title('brightness_range')
axes[1].set_title('original')
# Out:
# Text(0.5, 1.0, 'original')

# %%
fig,axes = plt.subplots(3,3,figsize=(5,5))
datagen = ImageDataGenerator(brightness_range=[0.2,3])
it = datagen.flow(expanded_sample, batch_size=5)
for i in range(9):
  batch = it.next()
  axes[int(i/3),i%3].imshow(batch[0].astype('uint8'))
  axes[int(i/3),i%3].get_xaxis().set_visible(False)
  axes[int(i/3),i%3].get_yaxis().set_visible(False)

# %%
ig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(shear_range=.5)
it = datagen.flow(expanded_sample, batch_size=1)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[0].set_title('shear_range')
axes[1].set_title('original')
# Out:
# Text(0.5, 1.0, 'original')

# %%
ig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(zoom_range=.3)
it = datagen.flow(expanded_sample, batch_size=1)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[0].set_title('zoom_range')
axes[1].set_title('original')
# Out:
# Text(0.5, 1.0, 'original')

# %%
ig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(channel_shift_range=.9)
it = datagen.flow(expanded_sample, batch_size=1)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[0].set_title('channel_shift_range')
axes[1].set_title('original')
# Out:
# Text(0.5, 1.0, 'original')

# %%
ig,axes = plt.subplots(1,2,figsize=(5,5))
datagen = ImageDataGenerator(fill_mode='nearest')
it = datagen.flow(expanded_sample, batch_size=1)
batch = it.next()
axes[0].imshow(batch[0].astype('uint8'))
axes[1].imshow(img)
axes[0].get_xaxis().set_visible(False)
axes[0].get_yaxis().set_visible(False)
axes[1].get_xaxis().set_visible(False)
axes[1].get_yaxis().set_visible(False)
axes[0].set_title('channel_shift_range')
axes[1].set_title('original')
# Out:
# Text(0.5, 1.0, 'original')

# %% [markdown]
# # create image data augmentation generator

# %%
datagen = ImageDataGenerator(featurewise_center=True,
                             rotation_range=(0-30),
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             brightness_range=[0.5,1.5],
                             shear_range=0.2, zoom_range=0.2,
                            #  channel_shift_range=0.2,
                             horizontal_flip=True, vertical_flip=True,
                            #  fill_mode='nearest',
                              # rescale=1./255, 
                              # data_format='channels_last'
                             )

# %%
it = datagen.flow(expanded_sample, batch_size=5)

# %%
datagen

# %%
(it.next()).shape
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# (1, 169, 301, 3)

# %%
fig,axes = plt.subplots(5,5,figsize=(10,10))
aug_imag = []
# fig.tight_layout()
for i in range(25):
  batch = it.next()
  aug_imag.append(batch[0].astype('uint8'))
  axes[int(i/5),i%5].imshow(batch[0].astype('uint8'))
  axes[int(i/5),i%5].get_xaxis().set_visible(False)
  axes[int(i/5),i%5].get_yaxis().set_visible(False)
  axes[int(i/5),i%5].get_xaxis().set_visible(False)
  axes[int(i/5),i%5].get_yaxis().set_visible(False)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
aug_imag[0]
# Out:
# array([[[121, 113, 108],
#         [123, 113, 108],
#         [123, 113, 108],
#         ...,
#         [  2,   9,   2],
#         [  2,   9,   2],
#         [  1,   9,   1]],
#
#        [[121, 113, 108],
#         [123, 113, 108],
#         [123, 113, 108],
#         ...,
#         [  1,   9,   1],
#         [  1,   8,   1],
#         [  1,   8,   1]],
#
#        [[120, 113, 108],
#         [123, 113, 108],
#         [123, 113, 108],
#         ...,
#         [  0,   7,   0],
#         [  0,   7,   0],
#         [  0,   7,   0]],
#
#        ...,
#
#        [[ 27,  35,  24],
#         [ 27,  35,  24],
#         [ 27,  35,  24],
#         ...,
#         [ 46,  67,  16],
#         [ 46,  67,  16],
#         [ 46,  67,  16]],
#
#        [[ 27,  35,  24],
#         [ 27,  35,  24],
#         [ 27,  35,  24],
#         ...,
#         [ 46,  67,  16],
#         [ 46,  67,  16],
#         [ 46,  67,  16]],
#
#        [[ 27,  35,  24],
#         [ 27,  35,  24],
#         [ 27,  35,  24],
# ...

# %%
batch[0].astype('uint8')
# Out:
# array([[[150, 173,  81],
#         [149, 172,  81],
#         [152, 175,  86],
#         ...,
#         [245, 255, 107],
#         [242, 255, 106],
#         [238, 255, 104]],
#
#        [[153, 176,  83],
#         [149, 172,  81],
#         [150, 173,  83],
#         ...,
#         [245, 255, 107],
#         [241, 255, 106],
#         [236, 255, 103]],
#
#        [[155, 178,  84],
#         [150, 173,  81],
#         [149, 172,  81],
#         ...,
#         [244, 255, 109],
#         [238, 255, 104],
#         [234, 255, 100]],
#
#        ...,
#
#        [[ 40,  80,  35],
#         [ 40,  80,  35],
#         [ 40,  78,  34],
#         ...,
#         [245, 255, 219],
#         [241, 255, 213],
#         [241, 255, 213]],
#
#        [[ 40,  80,  35],
#         [ 37,  76,  25],
#         [ 33,  71,  15],
#         ...,
#         [246, 255, 221],
#         [244, 255, 218],
#         [241, 255, 213]],
#
#        [[ 33,  71,  15],
#         [ 31,  70,  12],
#         [ 34,  71,  15],
# ...

# %%
plt.imshow(aug_imag[0])

# %%
#have to save this files
